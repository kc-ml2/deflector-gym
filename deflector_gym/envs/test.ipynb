# %%
import random
import numpy as np
from meent_env import MeentIndexEfield
import matplotlib.pyplot as plt

# %%
env = MeentIndexEfield()

# %%
struct = [random.choice([-1, 1]) for i in range(256)]

# %%
obs, _  = env.reset()

# %%
obs, _, _, _, _ = env.step(10)

# %%
plt.imshow(obs[0], cmap='jet')

# %%
obs.shape
# Out:
# (2, 256, 256)

# %%
plt.imshow(obs[0], cmap='jet')

# %%
env.step(0)
# Out:
# /home/anthony/deflector-gym/deflector_gym/envs/meent_utils.py:82: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:275.)
#   ucell = torch.tensor([[pattern_input]])
# (array([[[-0.53679379, -0.53679388, -0.53682255, ..., -0.53696494,
#           -0.53687935, -0.53682229],
#          [-0.50585273, -0.50585282, -0.50588217, ..., -0.50602797,
#           -0.50594033, -0.50588191],
#          [-0.47306539, -0.47306548, -0.47309551, ..., -0.47324465,
#           -0.473155  , -0.47309523],
#          ...,
#          [ 0.86755285,  0.86755293,  0.86757904, ...,  0.86770864,
#            0.86763075,  0.8675788 ],
#          [ 0.88318712,  0.8831872 ,  0.88321349, ...,  0.88334398,
#            0.88326555,  0.88321325],
#          [ 0.89244659,  0.89244667,  0.89247309, ...,  0.89260427,
# ...

# %%
env.step(0)
# Out:
# (array([[[-0.61841736, -0.61841736, -0.61841736, ..., -0.61841736,
#           -0.61841736, -0.61841736],
#          [-0.59164985, -0.59164985, -0.59164985, ..., -0.59164985,
#           -0.59164985, -0.59164985],
#          [-0.56289174, -0.56289174, -0.56289174, ..., -0.56289174,
#           -0.56289174, -0.56289174],
#          ...,
#          [ 0.94008701,  0.94008701,  0.94008701, ...,  0.94008701,
#            0.94008701,  0.94008701],
#          [ 0.95416419,  0.95416419,  0.95416419, ...,  0.95416419,
#            0.95416419,  0.95416419],
#          [ 0.96149385,  0.96149385,  0.96149385, ...,  0.96149385,
#            0.96149385,  0.96149385]],
#
#         [[-0.44372636, -0.44372636, -0.44372636, ..., -0.44372636,
#           -0.44372636, -0.44372636],
#          [-0.47883563, -0.47883563, -0.47883563, ..., -0.47883563,
#           -0.47883563, -0.47883563],
#          [-0.51233387, -0.51233387, -0.51233387, ..., -0.51233387,
#           -0.51233387, -0.51233387],
# ...
